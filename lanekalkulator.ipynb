# %% [markdown]
# # Lånekalkulator
#
# Dette er en arbeidsnotebook. Skriv kode i de tomme kodecellene og legg gjerne til flere celler underveis.
#
# Vi følger et lån måned for måned. Vi antar fast årlig rente, månedlig rente lik årlig rente delt på 12, betaling ved slutten av måneden og ingen gebyrer.
#
# $$\text{rentebeløp}=\text{restlån}\cdot r$$
#
# $$\text{avdrag}=\text{terminbeløp}-\text{rentebeløp}$$
#
# $$\text{nytt restlån}=\text{restlån}-\text{avdrag}$$
#
# Terminbeløpet er fast. Når renten er fast, synker rentedelen og avdragsdelen øker etter hvert som restlånet blir mindre.
#
# | Scenario | Beskrivelse | Lånebeløp | Årlig rente | Terminbeløp per måned |
# | --- | --- | ---: | ---: | ---: |
# | **A** | Referanse | 2 500 000 kr | 5 % | 15 000 kr |
# | **B** | Høyere terminbeløp | 2 500 000 kr | 5 % | 18 000 kr |
#
# Alle tallene er laget for oppgaven.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Kom i gang – de første månedene
#
# Beregn rentebeløp, avdrag og nytt restlån for de tre første månedene i scenario A. Bruk variabler og mellomregninger, men ikke løkke.
#
# Hvor mye av det første terminbeløpet går til renter, og hvor mye reduserer lånet?
#
# Kontroll etter første måned:
#
# - rentebeløp: omtrent **10 416,67 kr**
# - nytt restlån: omtrent **2 495 416,67 kr**

# %%
# Beregn de første månedene her

# %% [markdown]
# ## Kjerne – følg lånet til det er nedbetalt
#
# Bruk scenario A. Lag en `while`-løkke som følger lånet måned for måned.
#
# Programmet skal:
#
# - avvise et terminbeløp på 0 kr eller mindre
# - varsle dersom terminbeløpet ikke dekker rentene den første måneden
# - skille mellom disse tilfellene og en simulering som kan gjennomføres
# - stoppe når lånet er nedbetalt eller etter høyst **1 200 måneder**
# - håndtere siste termin slik at avdraget ikke blir større enn restlånet
# - lagre startsaldoen og deretter restlånet etter hver måned
# - fortelle hvorfor løkken stoppet
#
# Tegn restlånet som funksjon av antall måneder.
#
# Kontroll: Scenario A blir nedbetalt etter omtrent **286 måneder**.
#
# <details><summary>Kort tips</summary><p>Her passer <code>if</code>, <code>elif</code> og <code>else</code> før løkken. Kombiner de to stoppbetingelsene i løkken med <code>and</code>. Start historikken med <code>historikk = [restlaan]</code>.</p></details>

# %%
# Lag simuleringen her

# %% [markdown]
# ## Lag en funksjon og sammenlign A og B
#
# Samle simuleringen i en funksjon som kan brukes med forskjellige lånebeløp, renter og terminbeløp. Returner både saldohistorikken og en status som forteller hvorfor simuleringen stoppet.
#
# Kall funksjonen direkte for scenario A og B. Rapporter status og antall måneder, og tegn de to saldohistorikkene i samme figur.
#
# Kontroll:
#
# - scenario A: omtrent **286 måneder**
# - scenario B: omtrent **208 måneder**

# %%
# Lag funksjonen og sammenlign A og B her

# %% [markdown]
# ## Les og kjør flere scenarioer
#
# Les inn den semikolonseparerte teksten i neste celle og bygg parallelle lister med scenarionavn, lånebeløp, renter, terminbeløp og boolske verdier for `skal_plottes`.
#
# Kjør lånefunksjonen for hvert scenario. Bruk `zip()` til å koble sammen verdiene, `enumerate()` til å nummerere rapporten og f-strenger til å vise resultatene. Tegn scenarioene som er merket `ja`, i samme figur.
#
# Resultatene for A og B skal stemme med de direkte funksjonskallene. Scenario C blir nedbetalt etter omtrent **617 måneder**. Forklar hvorfor `Test` ikke kan gjennomføres, og hvorfor forskjellen mellom scenario A og C blir så stor.
#
# <details><summary>Kort tips</summary><p>Bruk <code>splitlines()</code> til å dele teksten i rader og et utsnitt til å hoppe over overskriften. Del hver datarad med <code>split(";")</code>, pakk ut feltene og konverter dem før de legges i listene. Sammenlign teksten <code>ja</code> med <code>==</code> for å lage en boolsk verdi.</p></details>

# %%
laanedata = """scenario;laanebelop;aarlig_rente;terminbelop;skal_plottes
A;2500000;0.05;15000;ja
B;2500000;0.05;18000;ja
C;2500000;0.07;15000;ja
D;1500000;0.055;12000;ja
E;3000000;0.045;18000;nei
Test;2500000;0.07;14000;nei"""

# %%
# Les inn dataene, kjør scenarioene og lag rapport og figur her

# %% [markdown]
# ## Fordypning – utvikle modellen
#
# Velg én eller flere retninger, eller formuler din egen:
#
# - undersøk hvordan du kan lage en annuitetsvariant
# - la renten eller terminbeløpet endre seg underveis
# - legg inn ekstra innbetalinger på valgte tidspunkter
# - sammenlign samlet rentebeløp mellom flere scenarioer
# - lag en annen relevant visualisering eller videreutvikling av modellen
#
# Forklar spørsmålet du undersøker, valgene du gjør, og hva resultatene viser.

# %%
# Arbeid med fordypningen her
