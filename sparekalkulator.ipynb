# %% [markdown]
# # Sparekalkulator
#
# Dette er en arbeidsnotebook. Skriv kode i de tomme kodecellene og legg gjerne til flere celler underveis.
#
# Vi ser på sparing med et fast innskudd ved slutten av hver måned, positiv rente og ingen startsaldo. Med månedlig innskudd $M$, månedlig rente $r$ og antall måneder $n$ er sluttsaldoen
#
# $$
# S(n)=M\frac{(1+r)^n-1}{r}.
# $$
#
# Den månedlige renten finner vi fra årlig rente i prosent: $r=\frac{\text{årlig renteprosent}}{100\cdot 12}$.
#
# | Scenario | Beskrivelse | Årlig rente | Månedlig innskudd |
# | --- | --- | ---: | ---: |
# | **A** | Referanse | 4 % | 1 000 kr |
# | **B** | Høyere innskudd | 4 % | 1 500 kr |
# | **C** | Høyere rente | 7 % | 1 000 kr |

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Nivå 1 – variabler og regning
#
# Beregn sluttsaldoen etter **24, 60 og 120 måneder** for scenario A, B og C. Bruk variabler og mellomregninger, men ikke lag en funksjon ennå.
#
# Finn også hvor mye som er satt inn, og hvor mye av sluttsaldoen som er rentegevinst. Sammenlign A med B og A med C.
#
# Kontroll: Scenario A skal ha omtrent **66 299 kroner** etter 60 måneder.
#
# <details><summary>Tips til nivå 1</summary><p>Regn først om årlig renteprosent til månedlig rente. Den samme månedlige renten kan brukes for alle tidspunktene i ett scenario.</p></details>

# %%
# Arbeid med nivå 1 her

# %% [markdown]
# ## Nivå 2 – funksjoner
#
# Samle de gjentakende beregningene fra nivå 1 i en funksjon. Bruk funksjonen til å beregne scenario A, B og C etter 24, 60 og 120 måneder.
#
# Hvilke deler av beregningen slipper du nå å gjenta?
#
# <details><summary>Tips til nivå 2</summary><p>Se etter hvilke verdier som endres mellom beregningene. De er naturlige parametere. Beregningsresultatet bør returneres fra funksjonen.</p></details>

# %%
# Arbeid med nivå 2 her

# %% [markdown]
# ## Nivå 3 – lister, løkker og plotting
#
# Organiser navnene, rentene og innskuddene til de tre scenarioene i lister. Lag et NumPy-array med måneder fra 0 til 120, og bruk en løkke til å beregne og lagre én tidsserie for hvert scenario.
#
# Tegn alle tre spareforløpene i samme figur. Figuren skal ha navn på aksene, tittel og tegnforklaring. Forklar hva figuren viser som ikke var like tydelig fra enkeltverdiene.
#
# <details><summary>Tips til nivå 3</summary><p>Bruk én liste for navn, én for årlige renter og én for månedlige innskudd. Samme indeks må beskrive samme scenario i alle listene. Start med en tom resultatliste og legg til én tidsserie per runde i løkken.</p></details>

# %%
# Arbeid med nivå 3 her

# %% [markdown]
# <details>
# <summary><strong>Ekstra utfordring – organiser dataene på to måter</strong></summary>
# <p>Løs først nivå 3 med parallelle lister. Organiser deretter dataene slik:</p>
#
# ```python
# scenarier = [
#     ["A", 4, 1000],
#     ["B", 4, 1500],
#     ["C", 7, 1000],
# ]
# ```
#
# <p>Skriv en ny løkke som henter data fra hver indre liste. Hvilken organisering gjør sammenhengen mellom navnet og parameterne tydeligst?</p>
# </details>

# %%
# Arbeid med ekstra utfordring her

# %% [markdown]
# ## Valgfri utfordring – sluttsaldo som funksjon av innskuddet
#
# Undersøk hvordan sluttsaldoen etter **120 måneder** avhenger av det månedlige innskuddet. La innskuddet variere fra 500 til 3 000 kroner og tegn én kurve for 4 prosent årlig rente og én for 7 prosent.
#
# Hva viser figuren om virkningen av innskudd og rente over en tiårsperiode?

# %%
# Arbeid med den valgfrie utfordringen her
