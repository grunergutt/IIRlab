# %% [markdown]
# # Teknologidiffusjon med logistisk vekst
#
# Dette er en arbeidsnotebook. Skriv kode i de tomme kodecellene og legg gjerne til flere celler underveis.
#
# En bedrift lanserer en ny digital bestillings- og kundeløsning i tre hypotetiske markedsområder. Vi modellerer antall brukere med logistisk vekst:
#
# $$
# P(t)=\frac{K}{1+A e^{-rt}}, \qquad A=\frac{K-P_0}{P_0}.
# $$
#
# Her er $t$ antall måneder etter lansering, $P_0$ antall brukere ved start, $r$ vekstraten og $K$ markedspotensialet. Alle tallene er laget for oppgaven.
#
# | Scenario | Beskrivelse | $P_0$ | $r$ | $K$ |
# | --- | --- | ---: | ---: | ---: |
# | **A** | Referanse | 300 | 0,18 | 5 000 |
# | **B** | Raskere spredning | 300 | 0,30 | 5 000 |
# | **C** | Mindre marked | 300 | 0,18 | 3 000 |

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Nivå 1 – variabler og regning
#
# Beregn antall brukere etter **6, 12 og 24 måneder** for scenario A, B og C. Bruk variabler og mellomregninger, men ikke lag en funksjon ennå.
#
# Sammenlign A med B og A med C. Hva forteller forskjellene?
#
# Kontroll: Scenario A skal ha omtrent **4 138 brukere** etter 24 måneder.
#
# <details><summary>Tips til nivå 1</summary><p>Beregn konstanten A i formelen én gang for hvert scenario. Bruk deretter den samme konstanten når du setter inn 6, 12 og 24 måneder i uttrykket. Bruk <code>np.exp(...)</code> til eksponentialuttrykket.</p></details>

# %%
# Arbeid med nivå 1 her

# %% [markdown]
# ## Nivå 2 – funksjoner
#
# Samle de gjentakende beregningene fra nivå 1 i en funksjon. Bruk funksjonen til å beregne scenario A, B og C etter 6, 12 og 24 måneder.
#
# Hvilke deler av beregningen slipper du nå å gjenta?
#
# <details><summary>Tips til nivå 2</summary><p>Se etter hvilke verdier som endres mellom beregningene. De er naturlige parametere. Beregningsresultatet bør returneres fra funksjonen.</p></details>

# %%
# Arbeid med nivå 2 her

# %% [markdown]
# ## Nivå 3 – lister, løkker og plotting
#
# Organiser navnene og parameterne til de tre scenarioene i lister. Lag et NumPy-array med måneder fra 0 til 36, og bruk en løkke til å beregne og lagre én tidsserie for hvert scenario.
#
# Tegn alle tre tidsseriene i samme figur. Figuren skal ha navn på aksene, tittel og tegnforklaring. Forklar hva figuren viser som ikke var like tydelig fra enkeltverdiene.
#
# <details><summary>Tips til nivå 3</summary><p>Bruk én liste for navn og én liste for hver parameter. Samme indeks må beskrive samme scenario i alle listene. Start med en tom resultatliste og legg til én tidsserie per runde i løkken.</p></details>

# %%
# Arbeid med nivå 3 her

# %% [markdown]
# <details>
# <summary><strong>Ekstra utfordring – organiser dataene på to måter</strong></summary>
# <p>Løs først nivå 3 med parallelle lister. Organiser deretter dataene slik:</p>
#
# ```python
# scenarier = [
#     ["A", 300, 0.18, 5000],
#     ["B", 300, 0.30, 5000],
#     ["C", 300, 0.18, 3000],
# ]
# ```
#
# <p>Skriv en ny løkke som henter data fra hver indre liste. Hvilken organisering gjør sammenhengen mellom navnet og parameterne tydeligst?</p>
# </details>

# %%
# Arbeid med ekstra utfordring her

# %% [markdown]
# ## Valgfri utfordring – sluttbrukere som funksjon av vekstraten
#
# Undersøk hvordan antall brukere etter **24 måneder** avhenger av vekstraten. La vekstraten variere fra 0,05 til 0,35 og lag en figur med vekstrate på x-aksen og antall brukere etter 24 måneder på y-aksen.
#
# A og B har samme startverdi og markedspotensial og ligger derfor på samme kurve. C får en egen kurve. Marker gjerne de opprinnelige scenarioene A, B og C.

# %%
# Arbeid med den valgfrie utfordringen her
